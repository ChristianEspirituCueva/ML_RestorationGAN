# %%
#Convertir OFF a BINVOX

# %%
import os
import glob
import importlib
import numpy as np
import scipy.ndimage
import binvox_rw

try:
    importlib.import_module('trimesh')
except ImportError:
    import subprocess
    subprocess.check_call(['pip', 'install', 'trimesh'])
import trimesh

# %%
data = 'ModelNet10'

target = {'bathtub', 'chair', 'dresser', 'night_stand', 'sofa', 'toilet', 'bed', 'desk', 'monitor', 'table'}

for c in target:
    for split in ['test', 'train']:
        for off in glob.glob(os.path.join(data, c, split, '*.off')):
            print("In Progress ...")
            voxname = os.path.join(data, c, split, os.path.basename(off).split('.')[0] + '.binvox')
            if os.path.exists(voxname):
                print(voxname, "generating...")
                continue
            os.system(f'binvox.exe -d 32 -cb -e {off}')
# Out:
# In Process ...
# ModelNet10\toilet\test\toilet_0345.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0346.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0347.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0348.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0349.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0350.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0351.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0352.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0353.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0354.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0355.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0356.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0357.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0358.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0359.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0360.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0361.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0362.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0363.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0364.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0365.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0366.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0367.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0368.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0369.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0370.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0371.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0372.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0373.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0374.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0375.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0376.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0377.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0378.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0379.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0380.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0381.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0382.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0383.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0384.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0385.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0386.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0387.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0388.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0389.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0390.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0391.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0392.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0393.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0394.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0395.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0396.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0397.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0398.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0399.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0400.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0401.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0402.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0403.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0404.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0405.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0406.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0407.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0408.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0409.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0410.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0411.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0412.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0413.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0414.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0415.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0416.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0417.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0418.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0419.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0420.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0421.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0422.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0423.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0424.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0425.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0426.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0427.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0428.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0429.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0430.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0431.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0432.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0433.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0434.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0435.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0436.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0437.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0438.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0439.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0440.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0441.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0442.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0443.binvox generating...
# In Process ...
# ModelNet10\toilet\test\toilet_0444.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0001.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0002.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0003.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0004.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0005.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0006.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0007.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0008.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0009.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0010.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0011.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0012.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0013.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0014.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0015.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0016.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0017.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0018.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0019.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0020.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0021.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0022.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0023.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0024.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0025.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0026.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0027.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0028.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0029.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0030.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0031.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0032.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0033.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0034.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0035.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0036.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0037.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0038.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0039.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0040.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0041.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0042.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0043.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0044.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0045.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0046.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0047.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0048.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0049.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0050.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0051.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0052.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0053.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0054.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0055.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0056.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0057.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0058.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0059.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0060.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0061.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0062.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0063.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0064.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0065.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0066.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0067.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0068.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0069.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0070.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0071.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0072.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0073.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0074.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0075.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0076.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0077.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0078.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0079.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0080.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0081.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0082.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0083.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0084.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0085.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0086.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0087.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0088.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0089.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0090.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0091.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0092.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0093.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0094.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0095.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0096.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0097.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0098.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0099.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0100.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0101.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0102.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0103.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0104.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0105.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0106.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0107.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0108.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0109.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0110.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0111.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0112.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0113.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0114.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0115.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0116.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0117.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0118.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0119.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0120.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0121.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0122.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0123.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0124.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0125.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0126.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0127.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0128.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0129.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0130.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0131.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0132.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0133.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0134.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0135.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0136.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0137.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0138.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0139.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0140.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0141.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0142.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0143.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0144.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0145.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0146.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0147.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0148.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0149.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0150.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0151.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0152.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0153.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0154.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0155.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0156.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0157.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0158.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0159.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0160.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0161.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0162.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0163.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0164.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_0165.binvox generating...
# In Process ...
# ModelNet10\toilet\train\toilet_
binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0090.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0091.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0092.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0093.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0094.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0095.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0096.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0097.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0098.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0099.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0100.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0101.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0102.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0103.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0104.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0105.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0106.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0107.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0108.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0109.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0110.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0111.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0112.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0113.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0114.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0115.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0116.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0117.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0118.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0119.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0120.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0121.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0122.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0123.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0124.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0125.binvox generating...
# In Process ...
# ModelNet10\night_stand\train\night_stand_0126.binvox generating...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# In Process ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6380\2794523973.py in <module>
#      11                 print(voxname, "generating...")
#      12                 continue
# ---> 13             os.system(f'binvox.exe -d 32 -cb -e {off}')
#
# KeyboardInterrupt:

# %%
## Generar agujeros
## Recibe archivos .binvox para convertirlos en array, editarlos, y volver a pasarlos a .binvox.

# %%
def get_fractured(source, min_points=1, max_points=3, min_radius=7, max_radius=10, sphere_chance=0.85):
    fractured = source.copy()

    # Escoger cantidad aleatoria de agujeros
    points = np.random.randint(min_points, max_points+1)

    # Todos los indices donde existan voxels
    idxs = np.argwhere(fractured == True) 

    # Escoger donde se encontraran los centros de los huecos
    centers = idxs[np.random.choice(len(idxs), points, False)]
    
    for x,y,z in centers:
        # Radio del hueco aleatorio
        r = np.random.randint(min_radius, max_radius+1) 
        xmin, xmax = max(0, x-r), x+r
        ymin, ymax = max(0, y-r), y+r
        zmin, zmax = max(0, z-r), z+r
        hole = np.ones_like(fractured)
        # Establecer los valores de los elementos del hueco
        hole[xmin:xmax, ymin:ymax, zmin:zmax] = False

        # Convertir la forma del hueco a una esfera si se cumple la probabilidad
        if np.random.rand() < sphere_chance:
            idxs = np.argwhere(hole == False)
            idxs_remove = np.sqrt((idxs[:,0] - x)**2 + (idxs[:,1] - y)**2 + (idxs[:,2] - z)**2)
            idxs_remove = idxs[idxs_remove > r]
            hole[idxs_remove[:,0], idxs_remove[:,1], idxs_remove[:,2]] = True
            
        # Crear agujero en fractured
        fractured *= hole
    
    return fractured

# %%
#@title Read  .binvox
# Abrir modelo .binvox y convertirlo a un array

for c in target:
    for split in ['test', 'train']:
        for binx in glob.glob(os.path.join(dataset, c, split, '*.binvox')):
            voxelname = os.path.join(dataset, c, split, os.path.basename(binx))
            if os.path.exists(voxelname):
                with open(voxelname, 'rb') as f:
                    model = binvox_rw.read_as_3d_array(f)
                    # Fracturar el modelo con los valores por defecto
                    fractured_model = get_fractured(model.data)
                    # Convertir geometrix voxelizada en una malla de triangulos usando el algoritmo Marching Cubes
                    mesh = trimesh.voxel.ops.matrix_to_marching_cubes(matrix=fractured_model, pitch=1.0)
                    
                    # Preparar y limiar la malla resultante
                    mesh.merge_vertices()
                    mesh.remove_duplicate_faces()
                    mesh.apply_scale(scaling=1.0)
                    
                    # Corregir normales invertidas en la malla
                    trimesh.repair.fix_inversion(mesh)
                    # Ajustar la orientacion de las caras de la malla
                    trimesh.repair.fix_winding(mesh)
                    modelname=os.path.basename(voxelname).split('.')[0]
                    print(f'ModelNet10/{c}/{split}/{modelname}.stl')
                    mesh.export(f'ModelNet10/{c}/{split}/{modelname}.stl', file_type='stl')
# ModelNet10/toilet/train/toilet_0333.stl
# ModelNet10/toilet/train/toilet_0334.stl
# ModelNet10/toilet/train/toilet_0335.stl
# ModelNet10/toilet/train/toilet_0336.stl
# ModelNet10/toilet/train/toilet_0337.stl
# ModelNet10/toilet/train/toilet_0338.stl
# ModelNet10/toilet/train/toilet_0339.stl
# ModelNet10/toilet/train/toilet_0340.stl
# ModelNet10/toilet/train/toilet_0341.stl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6380\286744248.py in <module>
#      12                     fractured_model = get_fractured(model.data)
#      13                     # Convertir geometrix voxelizada en una malla de triangulos usando el algoritmo Marching Cubes
# ---> 14                     mesh = trimesh.voxel.ops.matrix_to_marching_cubes(matrix=fractured_model, pitch=1.0)
#      15
#      16                     # Preparar y limiar la malla resultante
#
# ~\miniconda3\envs\ml\lib\site-packages\trimesh\voxel\ops.py in matrix_to_marching_cubes(matrix, pitch)
#     157     mesh = Trimesh(vertices=vertices,
#     158                    faces=faces,
# --> 159                    vertex_normals=normals)
#     160     return mesh
#     161
#
# ~\miniconda3\envs\ml\lib\site-packages\trimesh\base.py in __init__(self, vertices, faces, face_normals, vertex_normals, face_colors, vertex_colors, face_attributes, vertex_attributes, metadata, process, validate, merge_tex, merge_norm, use_embree, initial_cache, visual, **kwargs)
#     190             self.process(validate=validate,
#     191                          merge_tex=merge_tex,
# --> 192                          merge_norm=merge_norm)
#     193
#     194         # save reference to kwargs
#
# ~\miniconda3\envs\ml\lib\site-packages\trimesh\base.py in process(self, validate, merge_tex, merge_norm)
#     231             self.remove_infinite_values()
#     232             self.merge_vertices(merge_tex=merge_tex,
# --> 233                                 merge_norm=merge_norm)
#     234             # if we're cleaning remove duplicate
#     235             # and degenerate faces
#
# ~\miniconda3\envs\ml\lib\site-packages\trimesh\base.py in merge_vertices(self, merge_tex, merge_norm, digits_vertex, digits_norm, digits_uv)
#    1138             digits_vertex=digits_vertex,
#    1139             digits_norm=digits_norm,
# -> 1140             digits_uv=digits_uv)
#    1141
#    1142     def update_vertices(self, mask, inverse=None):
#
# ~\miniconda3\envs\ml\lib\site-packages\trimesh\grouping.py in merge_vertices(mesh, merge_tex, merge_norm, digits_vertex, digits_norm, digits_uv)
#      96
#      97     # check unique rows of referenced vertices
# ---> 98     u, i = unique_rows(stacked[referenced], keep_order=True)
#      99
#     100     # construct an inverse using the subset
#
# ~\miniconda3\envs\ml\lib\site-packages\trimesh\grouping.py in unique_rows(data, digits, keep_order)
#     462         # keeps order of original occurrence
#     463         return unique_ordered(
# --> 464             rows, return_index=True, return_inverse=True)[1:]
#     465     # returns values sorted by row-hash but since our row-hash
#     466     # were pretty much garbage the sort order isn't meaningful
#
# ~\miniconda3\envs\ml\lib\site-packages\trimesh\grouping.py in unique_ordered(data, return_index, return_inverse)
#     295     if return_index:
#     296         # re-order the index in the original array
# --> 297         result.append(index[order])
#     298     if return_inverse:
#     299         # create the new inverse from the order of the order
#
# KeyboardInterrupt:
